# %% [markdown]
# <a href="https://colab.research.google.com/github/divyansshu/pytorch/blob/main/custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
import numpy as np

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
import zipfile
from pathlib import Path

data_path = Path('/content/data')

with zipfile.ZipFile(data_path / 'pizza_steak_sushi.zip', 'r') as zip_ref:
  print('Unzipping pizza, steak and sushi data...')
  zip_ref.extractall(data_path)
# Out:
# Unzipping pizza, steak and sushi data...

# %%
train_dir = data_path / 'train'
test_dir = data_path / 'test'

train_dir, test_dir
# Out:
# (PosixPath('/content/data/train'), PosixPath('/content/data/test'))

# %%
import random
from PIL import Image

image_path_list = list(data_path.glob("*/*/*.jpg"))

random_image_path = random.choice(image_path_list)

image_class = random_image_path.parent.stem

image = Image.open(random_image_path)

print(f'Image path: {random_image_path}')
print(f'Image class: {image_class}')
print(f'Image height: {image.height}')
print(f'Image width: {image.width}')
image
# Out:
# Image path: /content/data/train/steak/2628106.jpg
# Image class: steak
# Image height: 512
# Image width: 512
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
img_as_array = np.asarray(image)
plt.imshow(img_as_array)
plt.title(f'Food: {image_class} | Image shape: {img_as_array.shape}')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))
